# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from webclient.image_ops import search as data
from webclient.image_ops import convert_images as ci
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
parentCrop, labelMask = data.trainableImages(ImageLabel.objects.all())

# %%
type(parentCrop)
# Out:
# numpy.ndarray

# %%
plt.subplot(1,3,1)
plt.imshow(parentCropImg)
plt.subplot(1,3,2)
plt.imshow(labelMask)
plt.subplot(1,3,3)
plt.imshow(parentCrop)
plt.hold
plt.imshow(labelMask*10+parentCrop[:,:,0])

# %%
import numpy as np

# %%
np.array()
